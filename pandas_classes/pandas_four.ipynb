# %%
# Lesson on data filtering
import pandas as pd

# %%
people = {
    "first" : ["Anish", "Ramish", "Samish", "Bamish", "Bamish"],
    "last" : ["Khadka", "Mainali", "Shrestha", "Karki", "Mainali"],
    "email" : ["anishramish56@gmail.com", "mainaliramish89@gmail.com", 
               "shresthasamish28@gmail.com", "bamishkarki819@gmail.com",
               "bamishmainali78@gmail.com"]
}
mydf = pd.DataFrame(people)
mydf
# Out:
#     first      last                       email
# 0   Anish    Khadka     anishramish56@gmail.com
# 1  Ramish   Mainali   mainaliramish89@gmail.com
# 2  Samish  Shrestha  shresthasamish28@gmail.com
# 3  Bamish     Karki    bamishkarki819@gmail.com
# 4  Bamish   Mainali   bamishmainali78@gmail.com

# %%
mydf['last'] == 'Mainali' # series with bool values, it corresponds with DF
# think of it as filter mask
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# Name: last, dtype: bool

# %%
filt = (mydf['last'] == 'Mainali')
mydf[filt]
# Out:
#     first     last                      email
# 1  Ramish  Mainali  mainaliramish89@gmail.com
# 4  Bamish  Mainali  bamishmainali78@gmail.com

# %%
mydf[mydf['last'] == 'Mainali'] # Same result
# Out:
#     first     last                      email
# 1  Ramish  Mainali  mainaliramish89@gmail.com
# 4  Bamish  Mainali  bamishmainali78@gmail.com

# %%
mydf.loc[filt]
# Out:
#     first     last                      email
# 1  Ramish  Mainali  mainaliramish89@gmail.com
# 4  Bamish  Mainali  bamishmainali78@gmail.com

# %%
mydf.loc[filt, 'email']
# Out:
# 1    mainaliramish89@gmail.com
# 4    bamishmainali78@gmail.com
# Name: email, dtype: object

# %%
# AND &
fil2 = (mydf['last'] == 'Mainali') & (mydf['first'] == 'Bamish')
mydf.loc[fil2]
# Out:
#     first     last                      email
# 4  Bamish  Mainali  bamishmainali78@gmail.com

# %%
# OR |
fil3 = (mydf['last'] == 'Mainali') | (mydf['last'] == 'Khadka')
mydf.loc[fil3]
# Out:
#     first     last                      email
# 0   Anish   Khadka    anishramish56@gmail.com
# 1  Ramish  Mainali  mainaliramish89@gmail.com
# 4  Bamish  Mainali  bamishmainali78@gmail.com

# %%
# Inverting a filer, ~
mydf.loc[~fil3]
# Out:
#     first      last                       email
# 2  Samish  Shrestha  shresthasamish28@gmail.com
# 3  Bamish     Karki    bamishkarki819@gmail.com

# %% [markdown]
# Filtering Real Data

# %%
# Filtering on real data 
df = pd.read_csv('Data/stack-overflow-developer-survey-2024/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('Data/stack-overflow-developer-survey-2024/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# ...

# %%
# high_salary = (df['salary'] > 70000) # example only

# Task1 : Find respondents from following countries : India, USA, UK, Germany
countries = ['United States', 'United Kingdom', 'India', 'Germany', 'Canada']
country_filter = df['Country'].isin(countries)
df.loc[country_filter, 'Country']
# Out:
# ResponseId
# 4         Canada
# 17        Canada
# 18         India
# 19       Germany
# 21       Germany
#           ...
# 65384      India
# 65414      India
# 65416      India
# 65429      India
# 65436    Germany
# Name: Country, Length: 11282, dtype: object

# %%
df.loc[country_filter, ['Country', 'LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith']]
# Out:
#             Country                             LanguageHaveWorkedWith  \
# ResponseId
# 4            Canada  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 17           Canada                                    Rust;TypeScript
# 18            India                     HTML/CSS;JavaScript;TypeScript
# 19          Germany              C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 21          Germany  Bash/Shell (all shells);HTML/CSS;PHP;Python;SQ...
# ...             ...                                                ...
# 65384         India                                                NaN
# 65414         India                                                NaN
# 65416         India                                                NaN
# 65429         India                                                NaN
# 65436       Germany           C;C++;Go;Lua;Objective-C;Python;Rust;SQL
#
#                                        DatabaseHaveWorkedWith
# ResponseId
# ...

# %%
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=113)
